# %%
import pandas as pd
df = pd.read_csv("../data-collection/archive_1/yc_companies.csv")
df
# Out:
#               slug          name        batch  status  \
# 0     afternoon-co  Afternoon.co    Fall 2024  Active
# 1             alex          Alex    Fall 2024  Active
# 2          apolink       Apolink    Fall 2024  Active
# 3        archilabs     ArchiLabs    Fall 2024  Active
# 4           archil        Archil    Fall 2024  Active
# ...            ...           ...          ...     ...
# 5685  voxel-energy  Voxel Energy  Winter 2026  Active
# 5686    zerosettle    ZeroSettle  Winter 2026  Active
# 5687        zymbly        Zymbly  Winter 2026  Active
# 5688           o11           o11  Winter 2026  Active
# 5689      sitefire      sitefire  Winter 2026  Active
#
#                           industry  \
# 0                              B2B
# 1                              B2B
# 2                      Industrials
# 3     Real Estate and Construction
# 4                              B2B
# ...                            ...
# 5685                   Industrials
# ...

# %%
batch = "Winter 2026"
industry = 'B2B'
filter_by_industry = True

if(filter_by_industry):
    filtered_df = df[(df['batch'] == batch) & (df['industry'] == industry)]
    print(filtered_df.value_counts("subindustry"))
else:
    filtered_df = df[df['batch'] == batch]
    print(filtered_df.value_counts("industry"))

# filtered_df
# Out:
# subindustry
# B2B                                       31
# B2B -> Infrastructure                     15
# B2B -> Engineering, Product and Design    14
# B2B -> Legal                               5
# B2B -> Analytics                           4
# B2B -> Finance and Accounting              4
# B2B -> Security                            3
# B2B -> Operations                          2
# B2B -> Productivity                        2
# B2B -> Sales                               2
# B2B -> Human Resources                     1
# B2B -> Marketing                           1
# B2B -> Retail                              1
# B2B -> Supply Chain and Logistics          1
# Name: count, dtype: int64
